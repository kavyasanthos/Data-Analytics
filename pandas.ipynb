# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv('/customers-100.csv')

# %%
print(df.head())
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
print(df.tail())
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 95     96  cb8E23e48d22Eae       Karl     Greer              Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra          Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer     Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes     Le, Nash and Cross
#
#                City          Country               Phone 1  \
# 95     East Richard           Guyana   (188)169-1674x58692
# 96     New Bradview        Sri Lanka       +1-846-706-2218
# 97       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# 98  Lake Elijahview            Aruba         (530)311-9786
# 99        Judymouth         Honduras         (753)813-6941
#
#                    Phone 2                           Email Subscription Date  \
# 95    001-841-293-3519x614                hhart@jensen.com        2022-01-30
# ...

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
print(df.columns)
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')

# %%
print(df.describe())
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
print(df['Customer Id'])
# Out:
# 0     DD37Cf93aecA6Dc
# 1     1Ef7b82A4CAAD10
# 2     6F94879bDAfE5a6
# 3     5Cef8BFA16c5e3c
# 4     053d585Ab6b3159
#            ...
# 95    cb8E23e48d22Eae
# 96    CeD220bdAaCfaDf
# 97    28CDbC0dFe4b1Db
# 98    c23d1D9EE8DEB0A
# 99    2354a0E336A91A1
# Name: Customer Id, Length: 100, dtype: object

# %%
print(df[0:5])
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
print(df.iloc[3])
# Out:
# Index                                              4
# Customer Id                          5Cef8BFA16c5e3c
# First Name                                     Linda
# Last Name                                      Olsen
# Company              Dominguez, Mcmillan and Donovan
# City                                      Bensonview
# Country                           Dominican Republic
# Phone 1                       001-808-617-6467x12895
# Phone 2                              +1-813-324-8756
# Email                    stanleyblackwell@benson.org
# Subscription Date                         2020-06-02
# Website                   http://www.good-lyons.com/
# Name: 3, dtype: object

# %%
df.dropna(how='any')
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.fillna(value=5)
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.apply(np.cumsum)
# Out:
#     Index                                        Customer Id  \
# 0       1                                    DD37Cf93aecA6Dc
# 1       3                     DD37Cf93aecA6Dc1Ef7b82A4CAAD10
# 2       6      DD37Cf93aecA6Dc1Ef7b82A4CAAD106F94879bDAfE5a6
# 3      10  DD37Cf93aecA6Dc1Ef7b82A4CAAD106F94879bDAfE5a65...
# 4      15  DD37Cf93aecA6Dc1Ef7b82A4CAAD106F94879bDAfE5a65...
# ..    ...                                                ...
# 95   4656  DD37Cf93aecA6Dc1Ef7b82A4CAAD106F94879bDAfE5a65...
# 96   4753  DD37Cf93aecA6Dc1Ef7b82A4CAAD106F94879bDAfE5a65...
# 97   4851  DD37Cf93aecA6Dc1Ef7b82A4CAAD106F94879bDAfE5a65...
# 98   4950  DD37Cf93aecA6Dc1Ef7b82A4CAAD106F94879bDAfE5a65...
# 99   5050  DD37Cf93aecA6Dc1Ef7b82A4CAAD106F94879bDAfE5a65...
#
#                                            First Name  \
# 0                                              Sheryl
# 1                                       SherylPreston
# 2                                    SherylPrestonRoy
# ...

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
print(s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
import numpy as np

dates = pd.date_range('20230101', periods=6)
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
print(df)
# Out:
#                    A         B         C         D
# 2023-01-01  1.091497 -1.112499  0.197594  0.069810
# 2023-01-02 -1.290484 -0.291340  0.627719 -0.608697
# 2023-01-03 -1.660455  0.329806 -0.216351  2.341288
# 2023-01-04 -1.654293  1.084225  0.894761  0.367119
# 2023-01-05  2.492690  0.626634 -2.570859 -0.685384
# 2023-01-06 -0.848044  1.576278  0.577933  0.205128

# %%
df1 = pd.DataFrame(np.random.randn(10, 4))
df2 = pd.DataFrame(np.random.randn(10, 4))

result = pd.concat([df1, df2])

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})

merged = pd.merge(left, right, on='key')

# %%
df = pd.DataFrame({'A': ['one', 'one', 'two', 'three'], 'B': ['A', 'B', 'C', 'A'], 'C': np.random.randn(4), 'D': np.random.randn(4)})

pivot = df.pivot_table(values='D', index='A', columns='B')

# %%
rng = pd.date_range('20230101', periods=100, freq='S')
ts = pd.Series(np.random.randn(len(rng)), index=rng)

# %%
import matplotlib.pyplot as plt

ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2023', periods=1000))
ts = ts.cumsum()
ts.plot()
plt.show()

# %%
df.to_csv('foo.csv')
df = pd.read_csv('foo.csv')

# %%
df.to_excel('foo.xlsx', sheet_name='Sheet1')
df = pd.read_excel('foo.xlsx', 'Sheet1', index_col=None, na_values=['NA'])
